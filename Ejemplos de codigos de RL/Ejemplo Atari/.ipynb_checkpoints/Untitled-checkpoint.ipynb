# %%
from stable_baselines3.common.env_util import make_atari_env
from stable_baselines3.common.vec_env import VecFrameStack
from stable_baselines3 import A2C

# There already exists an environment generator
# that will make and wrap atari environments correctly.
# Here we are also multi-worker training (n_envs=4 => 4 environments)
vec_env = make_atari_env("PongNoFrameskip-v4", n_envs=4, seed=0)
# Frame-stacking with 4 frames
vec_env = VecFrameStack(vec_env, n_stack=4)

model = A2C("CnnPolicy", vec_env, verbose=1)
model.learn(total_timesteps=25_000)

obs = vec_env.reset()
while True:
    action, _states = model.predict(obs, deterministic=False)
    obs, rewards, dones, info = vec_env.step(action)
    vec_env.render("human")
# Out:
# Using cpu device
# Wrapping the env in a VecTransposeImage.
# ------------------------------------
# | time/                 |          |
# |    fps                | 383      |
# |    iterations         | 100      |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -1.75    |
# |    explained_variance | 0.102    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | 0.028    |
# |    value_loss         | 0.000291 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.4e+03  |
# |    ep_rew_mean        | -20.2    |
# | time/                 |          |
# |    fps                | 398      |
# |    iterations         | 200      |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -1.63    |
# |    explained_variance | -0.0595  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | 0.0469   |
# |    value_loss         | 0.000971 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.4e+03  |
# |    ep_rew_mean        | -20.2    |
# | time/                 |          |
# |    fps                | 402      |
# |    iterations         | 300      |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -1.43    |
# |    explained_variance | 0.0238   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | 0.0448   |
# |    value_loss         | 0.00136  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.56e+03 |
# |    ep_rew_mean        | -20.4    |
# | time/                 |          |
# |    fps                | 404      |
# |    iterations         | 400      |
# |    time_elapsed       | 19       |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -1.73    |
# |    explained_variance | -0.0028  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | 0.0337   |
# |    value_loss         | 0.000546 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.5e+03  |
# |    ep_rew_mean        | -20.5    |
# | time/                 |          |
# |    fps                | 404      |
# |    iterations         | 500      |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -1.69    |
# |    explained_variance | -0.384   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | -0.239   |
# |    value_loss         | 0.236    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.5e+03  |
# |    ep_rew_mean        | -20.5    |
# | time/                 |          |
# |    fps                | 405      |
# |    iterations         | 600      |
# |    time_elapsed       | 29       |
# |    total_timesteps    | 12000    |
# | train/                |          |
# |    entropy_loss       | -1.75    |
# |    explained_variance | 0.000288 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | -0.17    |
# |    value_loss         | 0.137    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.49e+03 |
# |    ep_rew_mean        | -20.6    |
# | time/                 |          |
# |    fps                | 407      |
# |    iterations         | 700      |
# |    time_elapsed       | 34       |
# |    total_timesteps    | 14000    |
# | train/                |          |
# |    entropy_loss       | -1.76    |
# |    explained_variance | 0.0108   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | 0.0575   |
# |    value_loss         | 0.00133  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.56e+03 |
# |    ep_rew_mean        | -20.4    |
# | time/                 |          |
# |    fps                | 408      |
# |    iterations         | 800      |
# |    time_elapsed       | 39       |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -1.75    |
# |    explained_variance | -0.0109  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | 0.0533   |
# |    value_loss         | 0.00105  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 3.55e+03  |
# |    ep_rew_mean        | -20.5     |
# | time/                 |           |
# |    fps                | 408       |
# |    iterations         | 900       |
# |    time_elapsed       | 44        |
# |    total_timesteps    | 18000     |
# | train/                |           |
# |    entropy_loss       | -1.76     |
# |    explained_variance | -0.000324 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 899       |
# |    policy_loss        | -0.421    |
# |    value_loss         | 0.226     |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.54e+03 |
# |    ep_rew_mean        | -20.4    |
# | time/                 |          |
# |    fps                | 409      |
# |    iterations         | 1000     |
# |    time_elapsed       | 48       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -1.73    |
# |    explained_variance | -0.0702  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | 0.0908   |
# |    value_loss         | 0.00303  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.51e+03 |
# |    ep_rew_mean        | -20.5    |
# | time/                 |          |
# |    fps                | 408      |
# |    iterations         | 1100     |
# |    time_elapsed       | 53       |
# |    total_timesteps    | 22000    |
# | train/                |          |
# |    entropy_loss       | -1.77    |
# |    explained_variance | -0.00106 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | -0.0311  |
# |    value_loss         | 0.046    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.52e+03 |
# |    ep_rew_mean        | -20.5    |
# | time/                 |          |
# |    fps                | 406      |
# |    iterations         | 1200     |
# |    time_elapsed       | 58       |
# |    total_timesteps    | 24000    |
# | train/                |          |
# |    entropy_loss       | -1.77    |
# |    explained_variance | 0.000891 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | -0.721   |
# |    value_loss         | 0.408    |
# ------------------------------------
# C:\Users\david\anaconda3\Lib\site-packages\gymnasium\utils\passive_env_checker.py:335: UserWarning: WARN: No render fps was declared in the environment (env.metadata['render_fps'] is None or not defined), rendering may occur at inconsistent fps.
#   logger.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 19
#      17 action, _states = model.predict(obs, deterministic=False)
#      18 obs, rewards, dones, info = vec_env.step(action)
# ---> 19 vec_env.render("human")
#
# File ~\anaconda3\Lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py:389, in VecEnvWrapper.render(self, mode)
#     388 def render(self, mode: Optional[str] = None) -> Optional[np.ndarray]:
# --> 389     return self.venv.render(mode=mode)
#
# File ~\anaconda3\Lib\site-packages\stable_baselines3\common\vec_env\dummy_vec_env.py:103, in DummyVecEnv.render(self, mode)
#      96 def render(self, mode: Optional[str] = None) -> Optional[np.ndarray]:
#      97     """
#      98     Gym environment rendering. If there are multiple environments then
#      99     they are tiled together in one image via ``BaseVecEnv.render()``.
#     100
#     101     :param mode: The rendering type.
#     102     """
# --> 103     return super().render(mode=mode)
#
# File ~\anaconda3\Lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py:264, in VecEnv.render(self, mode)
#     261     import cv2
#     263     cv2.imshow("vecenv", bigimg[:, :, ::-1])
# --> 264     cv2.waitKey(1)
#     265 else:
#     266     return bigimg
#
# KeyboardInterrupt:
